# %%
import random
import getpass
import sys
from datetime import datetime

# %% [markdown]
# # User accounts details

# %%
username = ["Ad27951972","Ed10251973","Li10821983","Br17842005","Ka21391988","Sc5642002","Ca16352007","Al8352012","Br16561983","Li11641990",
"Ke9311975","Be12662016" ]

password = ["643633785","249991339","839345644","62113069","396937335","712401872","553185300","500374578","372251582","250973674","250605844",
"95409481"]

cust_id=["9319408427","9307610147","9565151621","9061523118","9651217325","9495427070","9624882730","9363519799","9737399627","9401606678",
"9284370030"]

custname=["Eduardo Madden","Lilah Acosta","Brooklyn Malone","Katrina Knox","Scarlet Kim","Camryn Larsen","Alberto Coffey","Brooklyn Shaw","Lizbeth Cowan","Keyla Kane","Bernard Flynn"]

branchname=[]

accountno = ["903500593797","909735994634","984678834197","899737188918","971689132701","890101245163","899911390004","958298417589","910667267266",
"969117648141","967802827544"]

fname = ["Eduardo","Lilah","Brooklyn","Katrina","Scarlet","Camryn","Alberto","Brooklyn","Lizbeth","Keyla","Bernard"]

lname = ["Madden","Acosta","Malone","Knox","Kim","Larsen","Coffey","Shaw","Cowan","Kane","Flynn"]

dob = ["02-06-1705","30-05-2007","03-08-1969","03-11-1994","13-07-2013","03-09-1971","14-10-1976","13-05-2013","30-06-2005","27-04-2003","14-02-1994"]

address=['A','B','A','B','A','B','A','B','A','B','A']

contact=['A','B','A','B','A','B','A','B','A','B','A']

balance=[4890017,5370109,2727482,6647019,6033197,4838109,8129163,5625765,4060459,8101244,9340295]

credit=[]

debit=[]

beneficiary = [[["Amoeba Singh","234AE1Y","Python Bank","100"]],
               [["Kentucky Chaddha","234AE1Y","Python Bank","100"]],
               [["Ohio Allimatti","234AE1Y","Python Bank","100"]],
               [["Sharmaji Waah Waah","234AE1Y","Python Bank","100"]],
               [["Neele Gagan","234AE1Y","Python Bank","100"]],
               [["Amoeba Singh","234AE1Y","Python Bank","100"]],
               [["Kentucky Chaddha","234AE1Y","Python Bank","100"]],
               [["Ohio Allimatti","234AE1Y","Python Bank","100"]],
               [["Sharmaji Waah Waah","234AE1Y","Python Bank","100"]],
               [["Neele Gagan","234AE1Y","Python Bank","100"]]
              ]

branchcode=[]

cc = [ ["CreditCard_1","Credit_Balance","PIN","Card_No"],
      ["CreditCard_2","Credit_Balance","PIN","Card_No"],
      ["CreditCard_3","Credit_Balance","PIN","Card_No"],
      ["CreditCard_4","Credit_Balance","PIN","Card_No"],
      ["CreditCard_5","Credit_Balance","PIN","Card_No"],
      ["CreditCard_6","Credit_Balance","PIN","Card_No"],
      ["CreditCard_7","Credit_Balance","PIN","Card_No"],
      ["CreditCard_8","Credit_Balance","PIN","Card_No"],
      ["CreditCard_9","Credit_Balance","PIN","Card_No"],
      ["CreditCard_10","Credit_Balance","PIN","Card_No"],
      ["CreditCard_11","Credit_Balance","PIN","Card_No"] ]


dc = [ ["DebitCard_1","Credit_Balance","PIN","Card_No"],
      ["DebitCard_2","Credit_Balance","PIN","Card_No"],
      ["DebitCard_3","Credit_Balance","PIN","Card_No"],
      ["DebitCard_4","Credit_Balance","PIN","Card_No"],
      ["DebitCard_5","Credit_Balance","PIN","Card_No"],
      ["DebitCard_6","Credit_Balance","PIN","Card_No"],
      ["DebitCard_7","Credit_Balance","PIN","Card_No"],
      ["DebitCard_8","Credit_Balance","PIN","Card_No"],
      ["DebitCard_9","Credit_Balance","PIN","Card_No"],
      ["DebitCard_10","Credit_Balance","PIN","Card_No"],
      ["DebitCard_11","Credit_Balance","PIN","Card_No"] ]



#card = ["9319408427","9307610147","9565151621","9061523118","9651217325","9495427070","9624882730","9363519799","9737399627","9401606678","9284370030"]

mpin=['1212','2121','3134','1212','2121','3134','1212','2121','3134','1212','2121']

# %% [markdown]
# # Different Functions to be used in the operations, but called by the METHOD - OPERATION

# %%
def account(args):
    print("\n\nName : \t\t\t",fname[args])
    print("Name : \t\t\t",lname[args])
    print("Account Number : \t",accountno[args])
    print("Account Balance : \t",balance[args],"\n\n")
    print("\nWould you like to update something :\n\t1: YES\n\t2: NO")
    inp = int(input())
    if inp ==1:
        accountupdate(args)
    else:
        options(args)

def accountupdate(args):
    print("What would you like to update :\tPRESS \n\t1: First Name\n\t2: Last Name\n\t3: Address\n\t4: Contact No")
    try:
        inp = int(input("\n\t"))
        if inp==1:
            inpu = input("First Name :\t")
            fname[args]=inpu
            print("Would to change something else too :\n\t1. YES\n\t2. NO\n\t")
            inputt = int(input(""))
            if inputt == 1:
                accountupdate(args)
            else:
                return
    
    
        elif inp==2:
            inpu = input("Last Name :\t")
            lname[args] = inpu
            print("Would to change something else too :\n\t1. YES\n\t2. NO\n\t")
            inputt = int(input(""))
            if inputt == 1:
                accountupdate(args)
            else:
                return

        elif inp==3:
            inpu = input("Address :\t")
            address[args] = inpu
            print("Would to change something else too :\n\t1. YES\n\t2. NO\n\t")
            inputt = int(input(""))
            if inputt == 1:
                accountupdate(args)
            else:
                return

        elif inp==4:
            inpu = input("Contact Number :\t")
            contact[args] = inpu
            print("Would to change something else too :\n\t1. YES\n\t2. NO\n\t")
            inputt = int(input(""))
            if inputt == 1:
                accountupdate(args)
            else:
                return

        else :
            print("Incorrect Value")
    except ValueError:
        print("Incorrect Input")

    
    
def balanced(args):
    print("Account Number : \t",accountno[args])
    print("Account Balance : \t",balance[args],"\n\n")
    options(args)


def beneficiaries(args):
    for i in range(0,len(beneficiary[args])):
        print(beneficiary[args][i])
    print("\nPress to see :\n\t1 : Beneficiary_Name\n\t2 : Beneficiary_Account_No\n\t3 : Beneficiary_Bank\n\t4 : Beneficiaary_Branch_Code\n")
    try:
        inp = int(input())
        print("\t",beneficiary[args][inp-1],"\n\n")
        beneficiaried(args)
        options(args)
    except ValueError:
        print("Error: You did not enter an integer.")
        beneficiaries(args)
        
    
#     beneficiary_named = beneficiary[args][0].split()
#     print("\n\nBeneficiary First Name : \t\t\t",beneficiary_named[0])
#     print("\nBeneficiary Last Name : \t\t\t",beneficiary_named[-1],"\n\n")
#     beneficiary=[ [[2],[4]], [[2],[4],[2],[4]] , [[2],[4],[2],[4],[2],[4]]  ]
    

    



def cardno(args):
    print("Credit Card Details :\t",cc[args])
    for i in range(0,len(cc[args])):
        print(cc[args][i])
    print("\nDebit Card Details :\t",dc[args])
    for i in range(0,len(dc[args])):
        print(dc[args][i])
        
    print("\nPRESS \n\t:1\t CHANGE PIN\n\t:2\t Go to OPTIONS ")
    inp2 = int(input())
    if inp2 ==1:
        print("\n\tPRESS \n\t1\t:\tCredit Card\n\t2\t:\tDebit Card\n\t")
        inp3 = int(input())
        if inp3 ==1:
            print("\t Enter the New PIN Number")
            print("Original PIN :\t",cc[args][2])
            cc[args][2]=int(input(""))
            print("New PIN \t:\t",cc[args][2])
        else:
            print("\t Enter the New PIN Number")
            print("Original PIN :\t",dc[args][2])
            dc[args][2]=int(input(""))
            print("New PIN \t:\t",dc[args][2])
    elif np2 ==2:
        options(args)
    else:
        print("Incorrect Value")


def fund_transfer(args):
    acctno = int(input("Enter the Account Nymber of the recipient\t:\t"))
    amt_transfer = int(input("Amount to transfer : \t"))
    if ( amt_transfer < ( 0.4 * (balance[args] ) ) ):
        print("Current Balance amount : ",balance[args], " in the BANK ACCOUNT :\t",accountno[args])
        print("Since amount to transfer is less than 40% of your current Balance amount, AMOUNT WILL BE TRANSFERRED\n\n")
        (balance[args]) = (balance[args]) - amt_transfer
        transfer(amt_transfer,acctno)
#         options(args)
    else:
        print("Sorry this much amount can't be paid as this is more than 40% of your account balance")
        fund_transfer(argss)


def mpined(args):
    print("\n\nCurrent MPIN : \t\t\t",mpin[args],"\n\n")
    try:
        inp = int(input("\n PRESS \n\t1 : To change MPIN\n\t2 : To go to OPTIONS\n\t3 : To EXIT\n\n\t"))
        if inp == 1:
            #if the user wanted to change MPIN else it had to be remove
            password = input("Enter the password : \t")
            while (pwd[args]!=password):
                inp = int(input("PRESS \n\t1\t:\t Correct PASSWORD\n\t2\t:\tTO EXIT in style ...\n"))
                if password!=1:
                    return
                else :
                    password = input("Enter the password : \t")
            #Taking the new MPIN and if changing it
            new_mpin = int(input("Enter your desired MPIN :\t"))
            mpin[args] = new_mpin
            print("PIN change successfull")
        elif inp == 2:
            print("\n")
            options(args)
        elif inp == 3:
            return
        else:
            print("Incorect Value")
    except ValueError:
        print("Error: You did not enter an integer.")
        mpined(args)
    

def transfer(x,y):
    posit = accountno.index(str(y))
    print("Balance before the transfer : ",balance[posit])
    print("Money transferred to the ",y," Account")
    balance[posit] = balance[posit] + x
    print("Balance after the transfer : ",balance[posit])

# %% [markdown]
# # Account Deletion

# %%
def deleted_Account(args):
    try :
        print("Account for the user with Username, {} has been deleted successfully.",format(uname.pop(args) ) )
        pwd.pop(args)
        custid.pop(args)
        custname.pop(args)
        accountno.pop(args)
        fname.pop(args)
        lname.pop(args)
        dob.pop(args)
        balance.pop(args)
        beneficiary.pop(args)
        card.pop(args)
        mpin.pop(args)

    except ValueError:
        print("It has been deleted successfully")

# %% [markdown]
# # BENEFICIARIES ADDITION & REMOVAL

# %%
def beneficiaried(args):
    
    print(len(beneficiary[args]))
    
    for i in range(0,len(beneficiary[args])):
        print("The data at position ",i," is ",beneficiary[args][i],"\n\n")
    
        
        
    for i in range(0,len(beneficiary[args])):
        for j in range(0,4):
            if j == 0:
                print("--> ",i,"  -- NAME \t   :\t",beneficiary[args][i][j])
            elif j == 1:
                print("--> ",i,"  -- Account Number :\t",beneficiary[args][i][j])
            elif j == 2:
                print("--> ",i,"  -- BANK Name \t   :\t",beneficiary[args][i][j])
            else:
                print("--> ",i,"  -- IFSC Code \t   :\t",beneficiary[args][i][j],"\n\n")

            
        
    print("Would you like to :\t\n\t1 : ADD a Beneficiary \t2 : Delete a Beneficiary\n")
    ben_choice = int(input())
    
    if ben_choice == 1:
        def add_ben():
            print("\nEnter the Beneficiary's Details\t:\t")
            beneficiary[args].append([0,0,0,0])
            l = len(beneficiary[args])
            print(l)
            l=l-1
            print(l)
            beneficiary[args][l][0] = input("BENEFICIAR's Name \t:\t")
            beneficiary[args][l][1] = input("BENEFICIAR's Account Number :\t")
            beneficiary[args][l][2] = input("BENEFICIAR's Bank Name \t:\t")
            beneficiary[args][l][3] = input("BENEFICIAR's Bank IFSC code :\t")
            
            for i in range(0,len(beneficiary[args])):
                print("The data at position ",i," is ",beneficiary[args][i],"\n\n")
            
        add_ben()

    else :
        def rem_ben():
            print("Which Beneficiary you want to remove : \t")
            ben_rem = int(input())
            removed = beneficiary[args].pop(ben_rem)
            print("\n\nREMOVED DATA\n\n",removed,"\n\n")
        print("After deletion of the data")
        rem_ben()
        for i in range(0,len(beneficiary[args])):
            print("The data at position ",i," is ",beneficiary[args][i],"\n\n")
    

        
    
    for i in range(0,len(beneficiary)):
        print(beneficiary[i])

# %% [markdown]
# # Operation method it calls the required methods

# %%
def options(posi):
    print("\n\n1. Display account info\n2. Balance\n3. List of Beneficiaries\n4. List of card \n5. Fund Transfer \n6. Change MPIN \n7. DELETE THIS ACCOUNT\n8. EXIT\n\n")
    try:
        inp1 = int(input("\n\t"))
        if inp1==1:
            account(posi)
            #Option to update account info → after update → screen showing updated info
        elif inp1==2:
             balanced(posi)
             # Option to register new credit card → after add → back to screen
        elif inp1 ==3:
            beneficiaries(posi)
            # Option to add beneficiary → after add → list beneficiary
        elif inp1 == 4:
            cardno(posi)
        elif inp1 == 5:
            fund_transfer(posi)
            # Option to transfer fund → after transfer, update records → create entry for that transaction → back to screen
        elif inp1 ==6:
            mpined(posi)
            # Option to change mpin of allotted cards → after change → back to screen
        elif inp1 ==7:
            deleted_Account(posi)
            print("ACCOUNT DELETION Successfull\n")
        elif inp1 ==8:
            print("EXIT made in style\n")
            #return
            sys.exit()
        else:
            print("Invalid Input")
    except ValueError:
        print("You are in OPTIONS")
        print("Error: You did not enter an integer.")
        options(posi)

# %% [markdown]
# # New Account Creation

# %%
def account_creation():
    nam = input('Enter the name of the Account Holder : ')
    uname.append(nam)
    
    #Username
    pos = uname.index(nam)
    print(uname[pos])

    #Password
    passd = input('Enter the password for the account of ')
    pwd.append(passd)
    
    #Cust_ID
    cust = random.randint(9000000000,9999999999)
    while str(cust) in custid:
        cust = random.randint(9000000000,9999999999)
    print("Your CustID is : ",cust)
    custid.append(cust)
    
    #Cust Name
    fnam = input("Enter your first name :\t")
    lnam = input("Enter your lsat name  :\t")
    nammy = fnam+" "+lnam
    fname.append(fnam)
    lname.append(lnam)
    custname.append(nammy)
    

    #Accout no
    actno = random.randint(9000000000,9999995555)
    accountno.append(actno)
    
    #DOB
    print("Enter Your complete Date Of Birth")
    ye = int(input("Enter YEAR  \t ( YYYY format ) :\t"))
    mo = int(input("Enter Month \t ( MM format )   :\t"))
    dd = int(input("Enter Date  \t ( DD format )   :\t"))
    # string in yyyy-mm-dd format
    date_str = str(ye)+"-"+str(mo)+"-"+str(dd)
    # convert datetime object to string in dd-mm-yyyy format
    dob_is = (datetime.strptime(date_str, "%Y-%m-%d")).strftime("%d-%m-%Y")
    
    dob.append(dob_is)
    
    #BALANCE
    bal = int(input("How much are you depositing with us right now :\t"))
    balance.append(bal)
    
    #Card
    cardn = random.randint(9000000000,9999999999)
    while str(cardn) in card:
        cardn = random.randint(9000000000,9999999999)
    card.append(card)
    
    #MPIN
    mpined = int(input("Enter the 4 digit MPIN :\t"))
    mpin.append(mpined)

# %% [markdown]
# # Main functionality is working from here

# %%
def mained():
    username = input("Enter the username : \t")
    try:
        while ( username in uname ):
            pos = uname.index(username)
            print(pos,"\t:\tUSERNAME Position")
            password = getpass.getpass(prompt='Enter password: ')
            while (pwd[pos]!=password):
                inp = int(input("PRESS \n\t1\t:\tCorrect PASSWORD\n\t2\t:\tTO EXIT in style ...\n\t"))
                if inp!=1:
                    return  #return means exit
                else :
                    password = input("Enter the password : \t")
            print("Correct\n\n")
            options(pos)
        # If username is not valid or not available
        else:
            x = int(input("\n\nInvalid Username \nPress \n\t1: To open an account with us \n\t Anything to EXIT\t\n\n\t"))
            if x ==1:
                print("Voila")
                #ACCOUNT creation happening now
                #REGISTRATION happened
                account_creation()

            else:
                return
    except ValueError:
        print("INCORRECT VALUE ...")
        pass
    except SystemExit:
        print("Exit made ....")

# %%
mained()
# Out:
# Enter the username : 	Ka21391988
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4364\150045913.py in <module>
# ----> 1 mained()
#
# ~\AppData\Local\Temp\ipykernel_4364\2567208681.py in mained()
#       2     username = input("Enter the username : \t")
#       3     try:
# ----> 4         while ( username in uname ):
#       5             pos = uname.index(username)
#       6             print(pos,"\t:\tUSERNAME Position")
#
# NameError: name 'uname' is not defined

# %%
# %tb

# %%
Li10821983	839345644
